# %% [markdown]
# # KineCluE Tutorial - Difsol3
# This notebook is used for the KineCluE tutorial organised during the school Difsol3 in May 2026. <br>
#
# ### Basic Notebook usage
#
# A notebook can contain text cells or Python code cells. It also displays the output of a code cell below the cell. <br>
# To add a cell, click on the + (Insert a cell below) icon, or click outside a cell and press B.<br>
# To remove a cell click on it and click on the scissors (Cut this cell) icon or press X.<br>
# To change the content of cell between text (Markdown) or code, click on it and select from the dropdown menu.<br>
# To run a cell, click on it and click on the (Run this cell and advance) icon or press Shift + Enter. <br>
#
# ### Basic KineCluE usage in a notebook
#
# - To compute the analytical expression using the KineCluE software in the environment used during this tutorial, simply create a code cell and type:
#
# %run kineclue_main.py path_input/main_input.txt
#
# Then run the cell by pressing Shift + Enter.
#
# - To compute the numerical expression using the KineCluE software in a notebook, simply create a code cell and type:
#
# %run kineclue_num.py path_input/num_input.txt
#
# Then run the cell by pressing Shift + Enter.
#
# <br>
# The cell output will display the output of the calculation and, by default, the results will be stored in a created CALC/ folder.

# %%
###This is a code cell, enter your code here:
